# %% [markdown]
# # I Quelques fonctions utilitaires

# %%
def vsom(L1: list, L2: list):
    res = []
    for i in range(len(L1)):
        res.append(L1[i] + L2[i])
    return res

# %%
vsom([1, 2, 3], [4, 5, 6])
# Out:
# [5, 10, 15]
